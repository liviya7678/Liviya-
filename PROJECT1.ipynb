# %% [markdown]
# <a href="https://colab.research.google.com/github/liviya7678/Liviya-/blob/main/PROJECT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Admission%20Chance.csv")

# %%
df.head()
# Out:
#    Serial No  GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  \
# 0          1        337          118                  4   4.5   4.5  9.65
# 1          2        324          107                  4   4.0   4.5  8.87
# 2          3        316          104                  3   3.0   3.5  8.00
# 3          4        322          110                  3   3.5   2.5  8.67
# 4          5        314          103                  2   2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No          400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4    SOP               400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df.describe()
# Out:
#         Serial No   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
df.shape
# Out:
# (400, 9)

# %%
print(df.columns)
# Out:
# Index(['Serial No', 'GRE Score', 'TOEFL Score', 'University Rating', ' SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df['Research'].value_counts()
# Out:
# Research
# 1    219
# 0    181
# Name: count, dtype: int64

# %%
x = df.drop(columns='Chance of Admit ', axis=1)
y = df['Chance of Admit ']

# %%
print(x)
# Out:
#      Serial No  GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  \
# 0            1        337          118                  4   4.5   4.5  9.65
# 1            2        324          107                  4   4.0   4.5  8.87
# 2            3        316          104                  3   3.0   3.5  8.00
# 3            4        322          110                  3   3.5   2.5  8.67
# 4            5        314          103                  2   2.0   3.0  8.21
# ..         ...        ...          ...                ...   ...   ...   ...
# 395        396        324          110                  3   3.5   3.5  9.04
# 396        397        325          107                  3   3.0   3.5  9.11
# 397        398        330          116                  4   5.0   4.5  9.45
# 398        399        312          103                  3   3.5   4.0  8.78
# 399        400        333          117                  4   5.0   4.0  9.66
#
#      Research
# 0           1
# 1           1
# ...

# %%
print(y)
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
sns.regplot( x='GRE Score', y='Chance of Admit ', data=df, fit_reg= True)
# Out:
# <Axes: xlabel='GRE Score', ylabel='Chance of Admit '>

# %%
sns.regplot( x='TOEFL Score', y='Chance of Admit ', data=df, fit_reg= True)
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='Chance of Admit '>

# %%
sns.regplot( x='University Rating', y='Chance of Admit ', data=df, fit_reg=True)
# Out:
# <Axes: xlabel='University Rating', ylabel='Chance of Admit '>

# %%
sns.regplot( x=' SOP', y='Chance of Admit ', data=df, fit_reg=True)
# Out:
# <Axes: xlabel=' SOP', ylabel='Chance of Admit '>

# %%
sns.regplot( x='LOR ', y='Chance of Admit ', data=df, fit_reg=True)
# Out:
# <Axes: xlabel='LOR ', ylabel='Chance of Admit '>

# %%
sns.regplot( x='CGPA', y='Chance of Admit ', data=df, fit_reg= True)
# Out:
# <Axes: xlabel='CGPA', ylabel='Chance of Admit '>

# %%
#data standardization
scaler = StandardScaler()

# %%
scaler.fit(x)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(x)

# %%
print(standardized_data)
# Out:
# [[-1.72772608  1.76210664  1.74697064 ...  1.16732114  1.76481828
#    0.90911166]
#  [-1.7190658   0.62765641 -0.06763531 ...  1.16732114  0.45515126
#    0.90911166]
#  [-1.71040552 -0.07046681 -0.56252785 ...  0.05293342 -1.00563118
#    0.90911166]
#  ...
#  [ 1.71040552  1.15124883  1.41704229 ...  1.16732114  1.42900622
#    0.90911166]
#  [ 1.7190658  -0.41952842 -0.72749202 ...  0.61012728  0.30403584
#   -1.09997489]
#  [ 1.72772608  1.41304503  1.58200646 ...  0.61012728  1.78160888
#    0.90911166]]

# %%
x = standardized_data
y = df['Chance of Admit ']

# %%
print(x)
print(y)
# Out:
# [[-1.72772608  1.76210664  1.74697064 ...  1.16732114  1.76481828
#    0.90911166]
#  [-1.7190658   0.62765641 -0.06763531 ...  1.16732114  0.45515126
#    0.90911166]
#  [-1.71040552 -0.07046681 -0.56252785 ...  0.05293342 -1.00563118
#    0.90911166]
#  ...
#  [ 1.71040552  1.15124883  1.41704229 ...  1.16732114  1.42900622
#    0.90911166]
#  [ 1.7190658  -0.41952842 -0.72749202 ...  0.61012728  0.30403584
#   -1.09997489]
#  [ 1.72772608  1.41304503  1.58200646 ...  0.61012728  1.78160888
#    0.90911166]]
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
class_distribution = y.value_counts()
print(class_distribution)
# Out:
# Chance of Admit
# 0.64    17
# 0.71    16
# 0.72    15
# 0.73    13
# 0.94    12
# 0.79    12
# 0.76    12
# 0.70    12
# 0.78    12
# 0.74    11
# 0.80    11
# 0.68    10
# 0.93     9
# 0.84     9
# 0.89     9
# 0.65     9
# 0.62     9
# 0.82     8
# 0.86     8
# 0.75     8
# 0.90     8
# 0.57     8
# 0.81     8
# 0.77     8
# 0.91     7
# 0.69     7
# 0.96     7
# 0.66     7
# 0.61     7
# 0.67     7
# 0.85     6
# 0.63     6
# 0.56     6
# 0.92     6
# 0.58     5
# 0.46     5
# 0.87     5
# 0.54     5
# 0.52     5
# 0.47     5
# 0.59     4
# 0.49     4
# 0.97     4
# 0.88     4
# 0.95     4
# 0.53     3
# 0.48     3
# 0.44     3
# 0.42     3
# 0.83     3
# 0.38     2
# 0.34     2
# 0.36     2
# 0.45     2
# 0.50     2
# 0.43     1
# 0.51     1
# 0.55     1
# 0.60     1
# 0.39     1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=y)
plt.title('Class Distribution in Target Variable')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
class_to_combine = 0  # Replace with the class value that has fewer than two instances
class_to_merge_with = 1  # Replace with the class value to merge with

# Combine classes in 'y'
y_combined = y.replace(class_to_combine, class_to_merge_with)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y_combined, test_size=0.2, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (400, 8) (320, 8) (80, 8)

# %%
print(y.shape, y_train.shape, y_test.shape)
# Out:
# (400,) (320,) (80,)

# %%
#training the ml model using support vector machine classifier
classifier = svm.SVC(kernel='linear')

# %%
y_train_categorical = pd.cut(y_train, bins=[0, 0.5, 0.75, 1], labels=['Low', 'Medium', 'High'])

# %%
print(y_train_categorical.unique())
# Out:
# ['Medium', 'High', 'Low']
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
classifier.fit(x_train, y_train_categorical)
# Out:
# SVC(kernel='linear')

# %%
#model evaluation

# %% [markdown]
# Accuracy score

# %%
#accuracy score of training data
y_train_prediction = classifier.predict(x_train)
training_data_accuracy = accuracy_score(y_train_categorical, y_train_prediction)

# %%
print('Accuracy score of training data :' , training_data_accuracy )
# Out:
# Accuracy score of training data : 0.828125

# %%
y_test_categorical = pd.cut(y_test, bins=[0, 0.5, 0.75, 1], labels=['Low', 'Medium', 'High'])

# %%
print(y_test_categorical.unique())
# Out:
# ['Low', 'High', 'Medium']
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
#accuracy score of test data
y_test_prediction = classifier.predict(x_test)
test_data_accuracy = accuracy_score(y_test_categorical, y_test_prediction)

# %%
print('Accuracy score of test data :' , test_data_accuracy )
# Out:
# Accuracy score of test data : 0.8375

# %% [markdown]
# MAKING A PREDICTIVE SYSTEM

# %%
input_data=(25,336,119,5,4,3.5,9.8,1)

#changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

#standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)
# Out:
# [[-1.51987933  1.67484124  1.91193482  1.67425725  0.59665321  0.05293342
#    2.01667732  0.90911166]]
# ['High']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
